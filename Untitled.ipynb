# %%
pip install vpython
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts jupyter-migrate.exe, jupyter-troubleshoot.exe and jupyter.exe are installed in 'C:\Users\danielle220038\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script qtpy.exe is installed in 'C:\Users\danielle220038\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting vpython
#   Using cached vpython-7.6.4-cp39-cp39-win_amd64.whl (3.5 MB)
# Collecting jupyter-server-proxy
#   Using cached jupyter_server_proxy-4.0.0-py3-none-any.whl (32 kB)
# Collecting numpy
#   Downloading numpy-1.25.2-cp39-cp39-win_amd64.whl (15.6 MB)
# Requirement already satisfied: ipykernel in c:\program files\python39\lib\site-packages (from vpython) (6.4.1)
# Collecting autobahn<27,>=22.6.1
#   Using cached autobahn-23.6.2-py2.py3-none-any.whl
#   WARNING: The script jupyter-console.exe is installed in 'C:\Users\danielle220038\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py.exe is installed in 'C:\Users\danielle220038\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts wamp.exe, xbrnetwork-ui.exe and xbrnetwork.exe are installed in 'C:\Users\danielle220038\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting txaio>=21.2.1
#   Using cached txaio-23.1.1-py2.py3-none-any.whl (30 kB)
# Collecting cryptography>=3.4.6
#   Using cached cryptography-41.0.3-cp37-abi3-win_amd64.whl (2.6 MB)
# Collecting hyperlink>=21.0.0
#   Using cached hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
# Requirement already satisfied: setuptools in c:\program files\python39\lib\site-packages (from autobahn<27,>=22.6.1->vpython) (57.4.0)
# Requirement already satisfied: cffi>=1.12 in c:\program files\python39\lib\site-packages (from cryptography>=3.4.6->autobahn<27,>=22.6.1->vpython) (1.14.6)
# Requirement already satisfied: pycparser in c:\program files\python39\lib\site-packages (from cffi>=1.12->cryptography>=3.4.6->autobahn<27,>=22.6.1->vpython) (2.20)
# Requirement already satisfied: idna>=2.5 in c:\program files\python39\lib\site-packages (from hyperlink>=21.0.0->autobahn<27,>=22.6.1->vpython) (3.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\program files\python39\lib\site-packages (from ipykernel->vpython) (1.4.3)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in c:\program files\python39\lib\site-packages (from ipykernel->vpython) (5.1.0)
# Requirement already satisfied: ipython-genutils in c:\program files\python39\lib\site-packages (from ipykernel->vpython) (0.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\program files\python39\lib\site-packages (from ipykernel->vpython) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\program files\python39\lib\site-packages (from ipykernel->vpython) (0.1.3)
# Requirement already satisfied: jupyter-client<8.0 in c:\program files\python39\lib\site-packages (from ipykernel->vpython) (7.0.2)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in c:\program files\python39\lib\site-packages (from ipykernel->vpython) (7.27.0)
# Requirement already satisfied: pickleshare in c:\program files\python39\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->vpython) (0.7.5)
# Requirement already satisfied: decorator in c:\program files\python39\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->vpython) (5.0.9)
# Requirement already satisfied: backcall in c:\program files\python39\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->vpython) (0.2.0)
# Requirement already satisfied: pygments in c:\program files\python39\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->vpython) (2.10.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\program files\python39\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->vpython) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\program files\python39\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->vpython) (0.18.0)
# Requirement already satisfied: colorama in c:\program files\python39\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->vpython) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\program files\python39\lib\site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->vpython) (0.8.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\program files\python39\lib\site-packages (from jupyter-client<8.0->ipykernel->vpython) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\program files\python39\lib\site-packages (from jupyter-client<8.0->ipykernel->vpython) (4.7.1)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\program files\python39\lib\site-packages (from jupyter-client<8.0->ipykernel->vpython) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in c:\program files\python39\lib\site-packages (from jupyter-client<8.0->ipykernel->vpython) (22.2.1)
# Requirement already satisfied: entrypoints in c:\program files\python39\lib\site-packages (from jupyter-client<8.0->ipykernel->vpython) (0.3)
# Requirement already satisfied: pywin32>=1.0 in c:\program files\python39\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->vpython) (301)
# Requirement already satisfied: wcwidth in c:\program files\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->vpython) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\program files\python39\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->vpython) (1.16.0)
# Collecting jupyter-console
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting qtconsole
#   Using cached qtconsole-5.4.3-py3-none-any.whl (121 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.0-py3-none-any.whl (139 kB)
# Requirement already satisfied: nbconvert in c:\program files\python39\lib\site-packages (from jupyter->vpython) (6.1.0)
# Requirement already satisfied: notebook in c:\program files\python39\lib\site-packages (from jupyter->vpython) (6.4.3)
# Collecting widgetsnbextension~=4.0.7
#   Using cached widgetsnbextension-4.0.8-py3-none-any.whl (2.3 MB)
# Collecting jupyterlab-widgets~=3.0.7
#   Using cached jupyterlab_widgets-3.0.8-py3-none-any.whl (214 kB)
# Collecting comm>=0.1.3
#   Using cached comm-0.1.4-py3-none-any.whl (6.6 kB)
# Collecting jupyter-core>=4.6.0
#   Using cached jupyter_core-5.3.1-py3-none-any.whl (93 kB)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Using cached prompt_toolkit-3.0.39-py3-none-any.whl (385 kB)
# Collecting traitlets<6.0,>=4.1.0
#   Using cached traitlets-5.9.0-py3-none-any.whl (117 kB)
# Collecting ipykernel
#   Using cached ipykernel-6.25.0-py3-none-any.whl (153 kB)
# Collecting debugpy<2.0,>=1.0.0
#   Using cached debugpy-1.6.7-cp39-cp39-win_amd64.whl (4.8 MB)
# Collecting psutil
#   Using cached psutil-5.9.5-cp36-abi3-win_amd64.whl (255 kB)
# Requirement already satisfied: packaging in c:\program files\python39\lib\site-packages (from ipykernel->vpython) (21.0)
# Collecting platformdirs>=2.5
#   Using cached platformdirs-3.10.0-py3-none-any.whl (17 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.5-cp39-cp39-win_amd64.whl (327 kB)
# Collecting importlib-metadata>=4.8.3
#   Using cached importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: jupyter-server>=1.0 in c:\program files\python39\lib\site-packages (from jupyter-server-proxy->vpython) (1.11.0)
# Collecting simpervisor>=0.4
#   Using cached simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.16.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: jinja2 in c:\program files\python39\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (3.0.1)
# Requirement already satisfied: argon2-cffi in c:\program files\python39\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (21.1.0)
# Requirement already satisfied: Send2Trash in c:\program files\python39\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\program files\python39\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.12.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\program files\python39\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (3.3.1)
# Requirement already satisfied: prometheus-client in c:\program files\python39\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.11.0)
# Requirement already satisfied: nbformat in c:\program files\python39\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (5.1.3)
# Requirement already satisfied: websocket-client in c:\program files\python39\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.2.1)
# Requirement already satisfied: requests-unixsocket in c:\program files\python39\lib\site-packages (from jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.2.0)
# Requirement already satisfied: sniffio>=1.1 in c:\program files\python39\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.2.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\program files\python39\lib\site-packages (from terminado>=0.8.3->jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.1.4)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\program files\python39\lib\site-packages (from aiohttp->jupyter-server-proxy->vpython) (2.0.4)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-win_amd64.whl (28 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.0-cp39-cp39-win_amd64.whl (44 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\program files\python39\lib\site-packages (from aiohttp->jupyter-server-proxy->vpython) (21.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp39-cp39-win_amd64.whl (61 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\program files\python39\lib\site-packages (from jinja2->jupyter-server>=1.0->jupyter-server-proxy->vpython) (2.0.1)
# Requirement already satisfied: jupyterlab-pygments in c:\program files\python39\lib\site-packages (from nbconvert->jupyter->vpython) (0.1.2)
# Requirement already satisfied: bleach in c:\program files\python39\lib\site-packages (from nbconvert->jupyter->vpython) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\program files\python39\lib\site-packages (from nbconvert->jupyter->vpython) (1.4.3)
# Requirement already satisfied: testpath in c:\program files\python39\lib\site-packages (from nbconvert->jupyter->vpython) (0.5.0)
# Requirement already satisfied: defusedxml in c:\program files\python39\lib\site-packages (from nbconvert->jupyter->vpython) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\program files\python39\lib\site-packages (from nbconvert->jupyter->vpython) (0.5.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\program files\python39\lib\site-packages (from nbconvert->jupyter->vpython) (0.8.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\program files\python39\lib\site-packages (from nbformat->jupyter-server>=1.0->jupyter-server-proxy->vpython) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\program files\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server>=1.0->jupyter-server-proxy->vpython) (0.18.0)
# Requirement already satisfied: webencodings in c:\program files\python39\lib\site-packages (from bleach->nbconvert->jupyter->vpython) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\program files\python39\lib\site-packages (from packaging->ipykernel->vpython) (2.4.7)
# Collecting qtpy>=2.0.1
#   Using cached QtPy-2.3.1-py3-none-any.whl (84 kB)
# Requirement already satisfied: requests>=1.1 in c:\program files\python39\lib\site-packages (from requests-unixsocket->jupyter-server>=1.0->jupyter-server-proxy->vpython) (2.26.0)
# Requirement already satisfied: urllib3>=1.8 in c:\program files\python39\lib\site-packages (from requests-unixsocket->jupyter-server>=1.0->jupyter-server-proxy->vpython) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python39\lib\site-packages (from requests>=1.1->requests-unixsocket->jupyter-server>=1.0->jupyter-server-proxy->vpython) (2021.5.30)
# Installing collected packages: traitlets, platformdirs, jupyter-core, prompt-toolkit, psutil, multidict, frozenlist, debugpy, comm, zipp, yarl, widgetsnbextension, qtpy, jupyterlab-widgets, ipykernel, async-timeout, aiosignal, txaio, simpervisor, qtconsole, jupyter-console, ipywidgets, importlib-metadata, hyperlink, cryptography, aiohttp, numpy, jupyter-server-proxy, jupyter, autobahn, vpython
# Successfully installed aiohttp-3.8.5 aiosignal-1.3.1 async-timeout-4.0.2 autobahn-23.6.2 comm-0.1.4 cryptography-41.0.3 debugpy-1.6.7 frozenlist-1.4.0 hyperlink-21.0.0 importlib-metadata-6.8.0 ipykernel-6.25.0 ipywidgets-8.1.0 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-core-5.3.1 jupyter-server-proxy-4.0.0 jupyterlab-widgets-3.0.8 multidict-6.0.4 numpy-1.25.2 platformdirs-3.10.0 prompt-toolkit-3.0.39 psutil-5.9.5 qtconsole-5.4.3 qtpy-2.3.1 simpervisor-1.0.0 traitlets-5.9.0 txaio-23.1.1 vpython-7.6.4 widgetsnbextension-4.0.8 yarl-1.9.2 zipp-3.16.2

# %%
from vpython import sphere, scene, vector, rate
import random
import numpy as np

class Particle:
    def __init__(self, pos, radius, velocity):
        self.sphere = sphere(pos=pos, radius=radius, color=vector(random.random(), random.random(), random.random()))
        self.velocity = velocity

    def update_position(self, dt):
        self.sphere.pos += self.velocity * dt

def detect_collision(p1, p2):
    dist = np.linalg.norm(p1.sphere.pos - p2.sphere.pos)
    return dist <= p1.sphere.radius + p2.sphere.radius

def handle_collision(p1, p2):
    # Calculate the new velocities after collision (assuming perfectly elastic collision)
    v1, v2 = p1.velocity, p2.velocity
    m1, m2 = p1.sphere.radius**3, p2.sphere.radius**3  # Assume equal densities for simplicity
    v1_new = v1 - 2 * m2 / (m1 + m2) * np.dot(v1 - v2, p1.sphere.pos - p2.sphere.pos) / np.linalg.norm(p1.sphere.pos - p2.sphere.pos)**2 * (p1.sphere.pos - p2.sphere.pos)
    v2_new = v2 - 2 * m1 / (m1 + m2) * np.dot(v2 - v1, p2.sphere.pos - p1.sphere.pos) / np.linalg.norm(p2.sphere.pos - p1.sphere.pos)**2 * (p2.sphere.pos - p1.sphere.pos)
    p1.velocity, p2.velocity = v1_new, v2_new

def main():
    # Simulation parameters
    num_particles = 50
    container_radius = 10
    particle_radius = 0.5
    max_velocity = 2

    particles = []
    for _ in range(num_particles):
        pos = vector(random.uniform(-container_radius, container_radius),
                     random.uniform(-container_radius, container_radius),
                     random.uniform(-container_radius, container_radius))
        velocity = vector(random.uniform(-max_velocity, max_velocity),
                          random.uniform(-max_velocity, max_velocity),
                          random.uniform(-max_velocity, max_velocity))
        particles.append(Particle(pos, particle_radius, velocity))

    while True:
        rate(60)  # Limit the frame rate to make the simulation visible

        # Update particle positions
        dt = 0.01  # Time step
        for particle in particles:
            particle.update_position(dt)

            # Handle collisions with container walls
            if abs(particle.sphere.pos.x) >= container_radius - particle.sphere.radius:
                particle.velocity.x *= -1
            if abs(particle.sphere.pos.y) >= container_radius - particle.sphere.radius:
                particle.velocity.y *= -1
            if abs(particle.sphere.pos.z) >= container_radius - particle.sphere.radius:
                particle.velocity.z *= -1

        # Handle collisions between particles
        for i in range(num_particles):
            for j in range(i + 1, num_particles):
                if detect_collision(particles[i], particles[j]):
                    handle_collision(particles[i], particles[j])

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\DANIEL~1\AppData\Local\Temp/ipykernel_18456/980854956.py in <module>
# ----> 1 from vpython import sphere, scene, vector, rate
#       2 import random
#       3 import numpy as np
#       4
#       5 class Particle:
#
# ModuleNotFoundError: No module named 'vpython'

# %%
import matplotlib.pyplot as plt
import numpy as np

class Particle:
    def __init__(self, position, radius, velocity):
        self.position = position
        self.radius = radius
        self.velocity = velocity

def detect_collision(p1, p2):
    dist = np.linalg.norm(p1.position - p2.position)
    return dist <= p1.radius + p2.radius

def handle_collision(p1, p2):
    # Calculate the new velocities after collision (assuming perfectly elastic collision)
    v1, v2 = p1.velocity, p2.velocity
    m1, m2 = p1.radius**3, p2.radius**3  # Assume equal densities for simplicity
    v1_new = v1 - 2 * m2 / (m1 + m2) * np.dot(v1 - v2, p1.position - p2.position) / np.linalg.norm(p1.position - p2.position)**2 * (p1.position - p2.position)
    v2_new = v2 - 2 * m1 / (m1 + m2) * np.dot(v2 - v1, p2.position - p1.position) / np.linalg.norm(p2.position - p1.position)**2 * (p2.position - p1.position)
    p1.velocity, p2.velocity = v1_new, v2_new

def update(particles, container_radius, dt):
    for particle in particles:
        # Update particle positions
        particle.position += particle.velocity * dt

        # Handle collisions with container walls
        for i in range(3):
            if abs(particle.position[i]) >= container_radius - particle.radius:
                particle.velocity[i] *= -1

    # Handle collisions between particles
    for i in range(len(particles)):
        for j in range(i + 1, len(particles)):
            if detect_collision(particles[i], particles[j]):
                handle_collision(particles[i], particles[j])

def plot_particles(particles, container_radius):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.set_xlim(-container_radius, container_radius)
    ax.set_ylim(-container_radius, container_radius)
    ax.set_zlim(-container_radius, container_radius)

    for particle in particles:
        ax.scatter(*particle.position, color='b', s=20)

    plt.show()

if __name__ == "__main__":
    # Simulation parameters
    num_particles = 50
    container_radius = 10
    particle_radius = 0.5
    max_velocity = 2
    dt = 0.01  # Time step

    particles = []
    for _ in range(num_particles):
        position = np.array([np.random.uniform(-container_radius, container_radius) for _ in range(3)])
        velocity = np.array([np.random.uniform(-max_velocity, max_velocity) for _ in range(3)])
        particles.append(Particle(position, particle_radius, velocity))

    num_steps = 500
    for step in range(num_steps):
        update(particles, container_radius, dt)
        plot_particles(particles, container_radius)
